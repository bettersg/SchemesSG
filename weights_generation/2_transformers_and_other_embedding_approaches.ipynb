# %% [markdown]
# # Other Embedding approaches
#
# - First written: 2021-05-10
# - Last edited: 2021-06-18

# %% [markdown]
# # 1. Current Challenges
#
# Currently there are 2 issues:
#
# 1. No good means of quantitatively evaluating model performance.
# - Solution 1: Human eval. Get a bunch of volunteers, (query, link) pairs, and ask volunteers to rate 1-5 for relevance (industry practice).
# - Solution 2: Logging. Put the system in the wild, use clicks as proxies for relevant and impressions / non-clicks otherwise.
#     - Problem is that logging is another whole issue altogether. Not a lightweight solution at all
#
# 2. Lack of data
# - LSI inferences are made with a small dataset of at most 100+ words
# - We could possibly increase the amount of data collected

# %% [markdown]
# # 2. Algorithm Changes
#
# LSI has its limitations: it works well when comparing two documents of similar length, but doesn't when one side is sparse on words / intent. A couple of ideas we can use to handle this:
#
# 1. Query Augmentation:
#     - Well practiced in [industry today](https://bytes.grubhub.com/search-query-embeddings-using-query2vec-f5931df27d79), but not sure if it's necessarily the best way.
#     - Expand the query by augmenting it with more synonyms
#     - Basic form: some kind of w2v "(approximate) nearest neighbour" retrieval, then concat
#
# 2. Better-quality embedding representation
# - LSI is good at topic finding and analysis, not so much for retrieval
# - What if we tried representing the embedding using some pretrained embeddings?
#     - Basic ones:
#         - w2v
#         - glove
#     - More advanced:
#         - bert-like transformers

# %% [raw]
# !../venv/bin/python -m pip install transformers[tf-cpu]
# !../venv/bin/python -m pip install pandas
# !../venv/bin/python -m pip install numpy
# !../venv/bin/python -m pip install ipywidgets
# !../venv/bin/python -m pip install jupyterlab_widgets
# !../venv/bin/python -m pip install -U sentence-transformers
# !../venv/bin/python -m pip install torch torchvision
# !../venv/bin/python -m pip install beautifulsoup4

# %%
import numpy as np
import torch
import pandas as pd
from transformers import pipeline
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('distilbert-base-cased')

# %%
# loading data
df_schemes = pd.read_csv('../schemes2.csv', encoding='mac_roman')
df_schemes.head()
# Out:
#                         Title                    Agency  \
# 0  Caregiver Training Program       Caregivers Alliance
# 1   Caregivers Support Centre       Caregivers Alliance
# 2              Family LifeAid       Red Cross Singapore
# 3             Food Assistance          A Packet of Rice
# 4                  Assistance  Filos Community Services
#
#                                          Description  \
# 0  Provides training to caregivers of persons wit...
# 1  Provides support to caregivers of persons with...
# 2  Identified households receive food vouchers ev...
# 3  A self setup group which distributes meal box ...
# 4  Bursaries, bread distribution and food rations...
#
#                    Who's it for  \
# 0                    Caregivers
# 1                    Caregivers
# 2  Low income,Need food support
# 3  Low income,Need food support
# 4  Low income,Need food support
#
#                                       What it gives  \
# 0             Educational programmes for caregivers
# 1                                    Emotional care
# 2  Financial assistance,Food,Educational programmes
# 3                                              Food
# 4                                  Food,Counselling
#
#                                                 Link  \
# 0          https://www.cal.org.sg/caregiver-training
# 1   https://www.cal.org.sg/caregivers-support-centre
# 2  https://www.redcross.sg/get-assistance/family-...
# 3            https://www.facebook.com/APacketOfRice/
# 4           https://www.filos.sg/services-assistance
#
#                                Background Image Link  \
# 0        https://chidnast.sirv.com/SchemesSG/CAL.jpg
# 1        https://chidnast.sirv.com/SchemesSG/CAL.jpg
# 2   https://chidnast.sirv.com/SchemesSG/redcross.jpg
# 3  https://chidnast.sirv.com/SchemesSG/apacketofr...
# 4      https://chidnast.sirv.com/SchemesSG/filos.jpg
#
#                  Scheme Type  \
# 0    Caregiver,Mental Health
# 1    Caregiver,Mental Health
# 2  Low Income,Food,Education
# 3            Low Income,Food
# 4            Low Income,Food
#
#                                   search_booster(WL)
# 0  Caregivers feeling overwhelmed. Burnout. Elder...
# 1  Caregivers feeling overwhelmed. Burnout. Elder...
# 2  needs help to get food, meal, hungry, have not...
# 3  Needs help to get food, meal, hungry, have not...
# 4  Need to buy daily necessities, food, have not ...

# %% [markdown]
# # Trying transformers from huggingface
#
# https://huggingface.co/transformers/notebooks.html

# %%
nlp_features = pipeline('feature-extraction')
output = nlp_features(df_schemes['Description'].tolist())
np.array(output).shape   # (Samples, Tokens, Vector Size)
# Out:
# (160, 150, 768)

# %%
np.array(output) # hmm it's a token-level summary, not sentence-level summary
# Out:
# array([[[ 3.46753061e-01, -1.03254691e-01, -1.16059974e-01, ...,
#          -1.92936182e-01,  2.02338740e-01,  8.29787254e-02],
#         [ 2.03822300e-01, -3.58859748e-01, -1.28057584e-01, ...,
#           6.05556071e-01,  2.29409888e-01,  9.13148075e-02],
#         [-1.24318346e-01, -6.78047240e-02, -1.56139255e-01, ...,
#           3.77754033e-01, -1.84957236e-01,  2.07725689e-01],
#         ...,
#         [ 1.90674633e-01, -8.14108551e-02, -3.30491364e-01, ...,
#           3.47913265e-01,  1.09129354e-01, -2.18179360e-01],
#         [ 3.73719096e-01, -5.64273335e-02, -2.42803887e-01, ...,
#           2.95044959e-01, -2.26940028e-03, -3.64589065e-01],
#         [ 2.22623460e-02,  5.80160730e-02, -1.93460673e-01, ...,
#          -2.21969038e-01, -2.56752253e-01, -2.11848006e-01]],
#
#        [[ 3.86439562e-01, -1.06316149e-01, -1.55976862e-01, ...,
#          -2.14574412e-01,  2.23219007e-01,  4.72031254e-03],
#         [ 1.85453758e-01, -3.71821046e-01, -1.44567832e-01, ...,
#           5.75556517e-01,  2.93644786e-01,  4.75528464e-02],
#         [ 7.24083483e-02, -6.16542958e-02, -2.43072256e-01, ...,
#           2.60003388e-01, -3.19609493e-02,  2.54305489e-02],
#         ...,
#         [ 1.58847526e-01, -1.71710983e-01, -3.50443393e-01, ...,
#           3.61582518e-01,  1.53114095e-01, -2.33043835e-01],
#         [ 3.34797949e-01, -1.16320044e-01, -2.48823524e-01, ...,
#           2.82722712e-01,  3.90131958e-03, -3.97816837e-01],
#         [ 6.15263134e-02,  6.31871074e-03, -2.45103419e-01, ...,
#          -2.80651689e-01, -2.20078945e-01, -3.11919898e-01]],
#
#        [[ 3.58486474e-01, -6.84912652e-02, -1.13134041e-01, ...,
#          -6.73934519e-02,  8.85405913e-02,  9.92944986e-02],
#         [ 1.45205021e-01, -5.57281733e-01,  1.67462289e-01, ...,
#           1.11647755e-01,  2.06098825e-01,  2.27762461e-02],
#         [-8.72118622e-02, -1.64711237e-01, -6.47513121e-02, ...,
#           3.37560475e-01, -5.01045823e-01, -4.64193076e-02],
#         ...,
#         [-5.21360449e-02,  2.44768232e-01,  5.02457246e-02, ...,
#           8.59965980e-02,  8.04348364e-02,  1.54348314e-01],
#         [ 4.99486923e-02,  2.43257582e-01,  1.36131942e-01, ...,
#           7.49755837e-03,  7.58926868e-02,  1.23995498e-01],
#         [ 2.40062132e-01,  1.29852369e-01,  6.69218302e-02, ...,
#           2.36528084e-01,  8.54508057e-02,  2.61457264e-01]],
#
#        ...,
#
#        [[ 2.67241716e-01, -5.20996749e-04, -1.50493443e-01, ...,
#          -8.85710567e-02, -1.49810277e-02,  1.62844524e-01],
#         [ 3.55928570e-01,  1.70279667e-01,  8.95891562e-02, ...,
#           4.49941695e-01, -2.77305655e-02, -7.98718259e-02],
#         [-3.83119106e-01, -4.12214249e-01,  2.61015650e-02, ...,
#          -1.99052542e-02,  9.91130248e-02, -2.27863919e-02],
#         ...,
#         [ 1.80944726e-02, -2.73423314e-01, -4.01746929e-02, ...,
#           1.50859118e-01, -3.58965576e-01,  1.92671031e-01],
#         [-2.54854083e-01, -3.31157565e-01, -2.01978207e-01, ...,
#           4.08418357e-01, -4.11001921e-01,  1.13425806e-01],
#         [-2.98367083e-01, -1.21254176e-02, -3.66086453e-01, ...,
#           5.61666667e-01, -1.36338860e-01,  2.41687909e-01]],
#
#        [[ 2.81274647e-01,  2.22917013e-02, -1.95921928e-01, ...,
#          -1.98333606e-01,  2.75528431e-01,  1.10111848e-01],
#         [ 1.03519633e-01, -5.21627426e-01, -3.74771059e-01, ...,
#          -4.32287566e-02,  5.56771159e-01,  4.86939877e-01],
#         [-1.74561784e-01, -2.30927363e-01,  7.07952818e-03, ...,
#           2.66961008e-01,  1.26094654e-01,  3.80715400e-01],
#         ...,
#         [-3.85772437e-03,  3.39165449e-01, -1.36717081e-01, ...,
#          -4.46844436e-02,  2.17409372e-01,  1.23132251e-01],
#         [-1.64474063e-02,  2.10147589e-01, -1.75538123e-01, ...,
#          -3.72153483e-02,  3.48806344e-02,  3.62933129e-02],
#         [ 1.42050177e-01,  2.19655618e-01, -5.76880686e-02, ...,
#           5.95634952e-02, -1.01702586e-01,  1.04543664e-01]],
#
#        [[ 3.66603076e-01, -4.53297272e-02, -2.36517146e-01, ...,
#          -1.72316656e-01,  1.27830625e-01,  6.69372827e-02],
#         [ 1.78900287e-01, -7.92299032e-01,  9.45072919e-02, ...,
#          -7.29825348e-02,  1.61647663e-01,  7.81048611e-02],
#         [ 3.28732818e-01,  7.26145357e-02, -1.45648897e-01, ...,
#          -1.51947871e-01, -5.57998046e-02, -1.21303760e-01],
#         ...,
#         [-2.41026372e-01,  1.60932481e-01, -3.16172957e-01, ...,
#           1.08635545e-01,  1.63491905e-01,  3.19990039e-01],
#         [-2.53007740e-01,  1.30383998e-01, -3.32752407e-01, ...,
#           1.34058401e-01,  1.24379024e-01,  3.25787723e-01],
#         [-1.07291281e-01,  1.82925388e-01, -3.83068711e-01, ...,
#           2.25010410e-01,  4.67913672e-02,  1.84569240e-01]]])

# %% [markdown]
# # Trying sentence_transformers instead
#
# Link: https://www.sbert.net/docs/usage/semantic_textual_similarity.html

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('paraphrase-distilroberta-base-v2')

# %%
embeddings = model.encode(df_schemes['Description'].tolist(), convert_to_tensor=True)

#Compute cosine-similarities
cosine_scores = util.pytorch_cos_sim(embeddings, embeddings)

# %%
cosine_scores
# Out:
# tensor([[1.0000, 0.8751, 0.2848,  ..., 0.2585, 0.2083, 0.2076],
#         [0.8751, 1.0000, 0.3767,  ..., 0.3165, 0.2771, 0.2854],
#         [0.2848, 0.3767, 1.0000,  ..., 0.1353, 0.4993, 0.3467],
#         ...,
#         [0.2585, 0.3165, 0.1353,  ..., 1.0000, 0.1863, 0.1581],
#         [0.2083, 0.2771, 0.4993,  ..., 0.1863, 1.0000, 0.3350],
#         [0.2076, 0.2854, 0.3467,  ..., 0.1581, 0.3350, 1.0000]])

# %%
def return_query(sentence, embeddings, df):
    query_emb = model.encode(sentence, convert_to_tensor=True)
    cos_sim = util.pytorch_cos_sim(query_emb, embeddings)
    cos_sim_series = pd.Series(cos_sim.numpy().flatten(), name='cos_sim')
    return df.join(cos_sim_series).sort_values('cos_sim', ascending=False)

# %%
test_sent = """
my client needs help as their family has lost a breadwinner and they need money to help with daily necessities during COVID. The child is also unable to afford schooling supplies such as computer"""

# %%
return_query(test_sent, embeddings, df_schemes).head(5)
# Out:
#                                           Title  \
# 158                         COVID-19 Assistance
# 18      ComCare Short-To-Medium-Term Assistance
# 102  The Straits Times School Pocket Money Fund
# 111                                  YMCA FACES
# 25            COVID-19 - Family Assistance Fund
#
#                                                 Agency  \
# 158                 NuLife Care & Counselling Services
# 18     Ministry of Social and Family Development (MSF)
# 102  The Straits Times School Pocket Money Fund (SPMF)
# 111           Young Men's Christian Association (YMCA)
# 25                              Beyond Social Services
#
#                                            Description  \
# 158  Information on various financial assistance sc...
# 18   Short to medium term assistance for those unab...
# 102  To alleviate the financial burden faced by par...
# 111  Short term financial assistance, bridging fund...
# 25   Covid 19 Family Assistance Fund Fund will go t...
#
#                                      Who's it for  \
# 158                   Elderly,Families,Low income
# 18                                     Low income
# 102             Children from low income families
# 111  Low income,Low income families,Special needs
# 25                                     Low income
#
#                                          What it gives  \
# 158                                      Referral,Food
# 18                                Financial assistance
# 102                 Financial assistance for education
# 111  Financial assistance for daily needs,Employmen...
# 25               Financial assistance,COVID-19 support
#
#                                                   Link  \
# 158           https://nulife.com.sg/covid-our-efforts/
# 18   https://www.msf.gov.sg/Comcare/Pages/Short-to-...
# 102  https://www.spmf.org.sg/primary-secondary-stud...
# 111  https://www.ymca.org.sg/community-services/fin...
# 25                  https://www.beyond.org.sg/faf-faq/
#
#                               Background Image Link  \
# 158  https://chidnast.sirv.com/SchemesSG/nulife.jpg
# 18      https://chidnast.sirv.com/SchemesSG/msf.jpg
# 102  https://chidnast.sirv.com/SchemesSG/stspmf.jpg
# 111    https://chidnast.sirv.com/SchemesSG/ymca.jpg
# 25   https://chidnast.sirv.com/SchemesSG/beyond.jpg
#
#                          Scheme Type  \
# 158                    COVID-19,Food
# 18                 Family,Low Income
# 102             Low Income,Education
# 111  Low Income,Special Needs,Family
# 25          Low Income,COVID-19,Food
#
#                                     search_booster(WL)   cos_sim
# 158  COVID, debt, pandemic, poor, hungry, nothing t...  0.584345
# 18        Need money for daily needs, low income, poor  0.583423
# 102  Children, disabled, schoolchildren, need compu...  0.554491
# 111  Financial assistance, money for daily expenses...  0.548327
# 25   Need money for daily needs, low income, poor, ...  0.532644

# %% [markdown]
# # 2.1 Does it work on shorter queries?

# %%
from collections import Counter
Counter([x for y in df_schemes['Who\'s it for'].apply(lambda x: x.split(',')).tolist() for x in y])
# Out:
# Counter({'Caregivers': 17,
#          'Low income': 30,
#          'Need food support': 13,
#          'Need education assistance': 1,
#          'Kidney patients': 4,
#          'PWDs': 9,
#          'New parents': 1,
#          'Cancer patients': 5,
#          'HIV patients': 5,
#          'Retrenched': 4,
#          'In need of employment': 1,
#          'Facing financial hardship': 2,
#          'Chinese community': 1,
#          'Children': 5,
#          'Unable to work': 1,
#          'Households with children attending student care': 1,
#          'Families': 8,
#          'Elderly': 20,
#          'Families who have just lost a breadwinner': 2,
#          'Ex-offenders': 2,
#          'Low income families': 24,
#          'Children from low income families': 12,
#          'In need of support from COVID-19': 1,
#          'In need of mortgage assistance': 6,
#          'Low income elderly': 1,
#          'Special needs children': 5,
#          'Youth-at-risk': 5,
#          'In debt': 4,
#          'Dyslexic children': 1,
#          'In need of mortage support': 1,
#          'Heart patients': 1,
#          'Leukaemia patients': 2,
#          'Students': 2,
#          'Malay Muslim community': 1,
#          'Need ILTC services': 2,
#          'General public': 2,
#          'Severely disabled': 1,
#          'Muslim community': 1,
#          'Parents': 3,
#          'Need shelter': 4,
#          'Dementia patients': 2,
#          'Stroke patients': 2,
#          'Diabetes patients': 2,
#          'Critical medical needs': 2,
#          'Low wage workers': 1,
#          'Special needs': 1,
#          'Facing end of life': 3,
#          'Teenagers facing pregnancy': 2,
#          'Pregnant individuals in distress': 1,
#          'In need of mental healthcare': 3,
#          'Facing abuse': 5,
#          'Homeless': 1,
#          'Unemployed': 2,
#          'In need of job': 1,
#          'Indian community': 4,
#          'In need of legal aid': 4,
#          'Women': 4,
#          'Facing harassment': 1,
#          'Undergoing divorce': 2,
#          'Elderly in need of mental healthcare': 1,
#          'Migrant workers': 1,
#          'PWD': 1,
#          'Struggling with loss': 2,
#          'Need mental healthcare': 1,
#          'Youth on probation': 1})

# %%
return_query("single parent", embeddings, df_schemes).head(5)  # a bit sketchy, but best attempt here and there.
# Out:
#                                                  Title  \
# 64         Home Ownership Plus Education (HOPE) Scheme
# 151                                   Various services
# 153                                    Family services
# 57                          Fresh Start Housing Scheme
# 80   Ministry of Education ñ Financial Assistance S...
#
#                                               Agency  \
# 64   Ministry of Social and Family Development (MSF)
# 151      Big Love Child Protection Specialist Centre
# 153               NuLife Care & Counselling Services
# 57               Housing and Development Board (HDB)
# 80                       Ministry of Education (MOE)
#
#                                            Description  \
# 64   Assistance for young, low-income parent(s) who...
# 151  Casework management; child protection; home-ba...
# 153  Casework management and counselling including ...
# 57   The Fresh Start Housing Scheme (Fresh Start) a...
# 80   Help needy Singaporean families reduce their b...
#
#                           Who's it for  \
# 64                 Low income families
# 151                            Parents
# 153                           Families
# 57                 Low income families
# 80   Children from low income families
#
#                                          What it gives  \
# 64   Financial assistance for daily expenses,Financ...
# 151  Casework,Child protection,Educational programm...
# 153                      Casework,Counselling,Referral
# 57             Financial assistance,Housing assistance
# 80                  Financial assistance for education
#
#                                                   Link  \
# 64   https://www.msf.gov.sg/assistance/Pages/Home-O...
# 151                        https://www.biglove.org.sg/
# 153                 https://nulife.com.sg/counselling/
# 57   https://www.hdb.gov.sg/cs/infoweb/residential/...
# 80   https://beta.moe.gov.sg/fees-assistance-awards...
#
#                                Background Image Link  \
# 64       https://chidnast.sirv.com/SchemesSG/msf.jpg
# 151  https://chidnast.sirv.com/SchemesSG/biglove.jpg
# 153   https://chidnast.sirv.com/SchemesSG/nulife.jpg
# 57       https://chidnast.sirv.com/SchemesSG/hdb.jpg
# 80       https://chidnast.sirv.com/SchemesSG/moe.jpg
#
#                              Scheme Type  \
# 64   Family,Low Income,Education,Housing
# 151                      Children,Family
# 153                               Family
# 57                               Housing
# 80                  Low Income,Education
#
#                                     search_booster(WL)   cos_sim
# 64   Family planning, low income, no money for food...  0.473492
# 151  child protection, abuse, family violence, chil...  0.383510
# 153  casework, counselling, family, individual, soc...  0.320471
# 57   Need money to tide over difficulties, money fo...  0.314973
# 80   School fees, students, child, children, study,...  0.307593

# %% [markdown]
# # 3. Latency issues
#
# tbd, seems like rn there isn't a strong need to explore faster models (e.g. distilbert)

# %%
# %%timeit  # at this point anything below 100ms latency is okay. This works primarily because df_schemes is small
return_query(test_sent, embeddings, df_schemes).head(5)
# Out:
# 56.7 ms ± 439 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # 4. Data Augmentation
#
# tbd, need to scrape data

# %%
import requests
from bs4 import BeautifulSoup

# %%
# sample 1 case
url = df_schemes.Link.iloc[1]

# %%
def scrape_text(url):
    try:
        r = requests.get(url)
        if r.status_code == 200:
            soup = BeautifulSoup(r.content, 'html.parser')
            text = soup.get_text() or ''
            return text.strip().replace('\n', '').replace('\t', '').replace('|', '')
    except Exception as e:
        print(e)  # this isn't great for productionalizing but i'm just here to scrape and clean text
        return ""

# %%
# don't do this at home
df_schemes['scraped_text'] = df_schemes['Link'].apply(scrape_text)
# Out:
# HTTPSConnectionPool(host='www.filos.sg', port=443): Max retries exceeded with url: /services-assistance (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1076)')))
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# HTTPSConnectionPool(host='www.ccf.org.sg', port=443): Max retries exceeded with url: /programmes-and-services/core-services/financial-assistance/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1076)')))
# HTTPSConnectionPool(host='beta.moe.gov.sg', port=443): Max retries exceeded with url: /fees-assistance-awards-scholarships/financial-assistance/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1076)')))
# Invalid URL 'www.boystown.org.sg': No schema supplied. Perhaps you meant http://www.boystown.org.sg?
# Invalid URL 'www.acmi.org.sg': No schema supplied. Perhaps you meant http://www.acmi.org.sg?

# %%
columns_of_interest = set(['Description', 'What it gives', 'search_booster(WL)', 'scraped_text'])
for c in columns_of_interest:
    df_schemes[c] = df_schemes[c].apply(str)

# %%
df_schemes['conjoined_text'] = df_schemes[['Description', 'What it gives', 'search_booster(WL)', 'scraped_text']].agg(' '.join, axis=1)

# %%
embeddings_with_more_info = model.encode(df_schemes['conjoined_text'].tolist(), convert_to_tensor=True)

#Compute cosine-similarities
cosine_scores_more_info = util.pytorch_cos_sim(embeddings_with_more_info, embeddings_with_more_info)

# %%
return_query(test_sent, embeddings_with_more_info, df_schemes).head(5)
# Out:
#                                           Title  \
# 25            COVID-19 - Family Assistance Fund
# 158                         COVID-19 Assistance
# 102  The Straits Times School Pocket Money Fund
# 2                                Family LifeAid
# 51                        Financial Asssistance
#
#                                                 Agency  \
# 25                              Beyond Social Services
# 158                 NuLife Care & Counselling Services
# 102  The Straits Times School Pocket Money Fund (SPMF)
# 2                                  Red Cross Singapore
# 51                        Children's Cancer Foundation
#
#                                            Description  \
# 25   Covid 19 Family Assistance Fund Fund will go t...
# 158  Information on various financial assistance sc...
# 102  To alleviate the financial burden faced by par...
# 2    Identified households receive food vouchers ev...
# 51   CCF Financial Assistance (FA) scheme aims to h...
#
#                           Who's it for  \
# 25                          Low income
# 158        Elderly,Families,Low income
# 102  Children from low income families
# 2         Low income,Need food support
# 51          Caregivers,Cancer patients
#
#                                         What it gives  \
# 25              Financial assistance,COVID-19 support
# 158                                     Referral,Food
# 102                Financial assistance for education
# 2    Financial assistance,Food,Educational programmes
# 51           Financial assistance for cancer patients
#
#                                                   Link  \
# 25                  https://www.beyond.org.sg/faf-faq/
# 158           https://nulife.com.sg/covid-our-efforts/
# 102  https://www.spmf.org.sg/primary-secondary-stud...
# 2    https://www.redcross.sg/get-assistance/family-...
# 51   https://www.ccf.org.sg/programmes-and-services...
#
#                                 Background Image Link  \
# 25     https://chidnast.sirv.com/SchemesSG/beyond.jpg
# 158    https://chidnast.sirv.com/SchemesSG/nulife.jpg
# 102    https://chidnast.sirv.com/SchemesSG/stspmf.jpg
# 2    https://chidnast.sirv.com/SchemesSG/redcross.jpg
# 51        https://chidnast.sirv.com/SchemesSG/ccf.jpg
#
#                    Scheme Type  \
# 25    Low Income,COVID-19,Food
# 158              COVID-19,Food
# 102       Low Income,Education
# 2    Low Income,Food,Education
# 51       Low Income,Healthcare
#
#                                     search_booster(WL)  \
# 25   Need money for daily needs, low income, poor, ...
# 158  COVID, debt, pandemic, poor, hungry, nothing t...
# 102  Children, disabled, schoolchildren, need compu...
# 2    needs help to get food, meal, hungry, have not...
# 51                      take care of child with cancer
#
#                                           scraped_text  \
# 25   COVID-19 Family Assistance FundAbout UsOrganis...
# 158  Covid-19 assistance - Our efforts  NuLife     ...
# 102  SPMF  Primary & Secondary Students Toggle navi...
# 2    Family LifeAidAbout usHeritage & Milestones70t...
# 51
#
#                                         conjoined_text   cos_sim
# 25   Covid 19 Family Assistance Fund Fund will go t...  0.604705
# 158  Information on various financial assistance sc...  0.579191
# 102  To alleviate the financial burden faced by par...  0.567199
# 2    Identified households receive food vouchers ev...  0.521717
# 51   CCF Financial Assistance (FA) scheme aims to h...  0.507862

# %%
return_query("single parent", embeddings_with_more_info, df_schemes).head(5)  # got a hit in number 3-4: surfacing pregnant teens!!!
# Out:
#                                                  Title  \
# 64         Home Ownership Plus Education (HOPE) Scheme
# 151                                   Various services
# 115                       Pregnancy Crisis and Support
# 114          Babes - A Helping Hand for Pregnant Teens
# 80   Ministry of Education ñ Financial Assistance S...
#
#                                               Agency  \
# 64   Ministry of Social and Family Development (MSF)
# 151      Big Love Child Protection Specialist Centre
# 115                     Pregnancy Crisis and Support
# 114        Babes - A Helping Hand for Pregnant Teens
# 80                       Ministry of Education (MOE)
#
#                                            Description  \
# 64   Assistance for young, low-income parent(s) who...
# 151  Casework management; child protection; home-ba...
# 115  For emotional support, guidance, help and refe...
# 114  Staff will discuss the various options availab...
# 80   Help needy Singaporean families reduce their b...
#
#                                           Who's it for  \
# 64                                 Low income families
# 151                                            Parents
# 115  Teenagers facing pregnancy,Pregnant individual...
# 114           Teenagers facing pregnancy,Youth-at-risk
# 80                   Children from low income families
#
#                                          What it gives  \
# 64   Financial assistance for daily expenses,Financ...
# 151  Casework,Child protection,Educational programm...
# 115                   Counselling for pregnancy crises
# 114                     Counselling for pregnant teens
# 80                  Financial assistance for education
#
#                                                   Link  \
# 64   https://www.msf.gov.sg/assistance/Pages/Home-O...
# 151                        https://www.biglove.org.sg/
# 115                https://www.pregnancycrisis.sg/Home
# 114  https://www.babes.org.sg/we-are-here-for-you/o...
# 80   https://beta.moe.gov.sg/fees-assistance-awards...
#
#                                Background Image Link  \
# 64       https://chidnast.sirv.com/SchemesSG/msf.jpg
# 151  https://chidnast.sirv.com/SchemesSG/biglove.jpg
# 115      https://chidnast.sirv.com/SchemesSG/pcs.jpg
# 114    https://chidnast.sirv.com/SchemesSG/babes.jpg
# 80       https://chidnast.sirv.com/SchemesSG/moe.jpg
#
#                              Scheme Type  \
# 64   Family,Low Income,Education,Housing
# 151                      Children,Family
# 115                        Youth-at-Risk
# 114                        Youth-at-Risk
# 80                  Low Income,Education
#
#                                     search_booster(WL)  \
# 64   Family planning, low income, no money for food...
# 151  child protection, abuse, family violence, chil...
# 115  Teenage Pregnancy, Pregnant, Young Mother, Bab...
# 114  Teenage Pregnancy, Pregnant, Young Mother, Bab...
# 80   School fees, students, child, children, study,...
#
#                                           scraped_text  \
# 64   Home Ownership Plus Education (HOPE) Scheme  M...
# 151  Big Love Child Protection Specialist Centre – ...
# 115                                               None
# 114  Our Services   Babes Pregnancy – Teenage Pregn...
# 80
#
#                                         conjoined_text   cos_sim
# 64   Assistance for young, low-income parent(s) who...  0.431200
# 151  Casework management; child protection; home-ba...  0.301316
# 115  For emotional support, guidance, help and refe...  0.291026
# 114  Staff will discuss the various options availab...  0.289167
# 80   Help needy Singaporean families reduce their b...  0.277014

# %% [markdown]
# # 5. Evaluation
#
# At this point, given only 100+ options to choose from and no tracking information, it's hard to do any kind of evaluation unless we log data and use implicit yeses and nos.

# %% [markdown]
# # 6. Productionalization

# %%
torch.save(embeddings_with_more_info, '../models/transformer/embeddings.pt')

# %%
df_schemes = df_schemes.rename(columns={'Background Image Link': 'Image', 'Title': 'Scheme'})

# %%
def return_query(sentence, embeddings, df, limit=50, rel_cap=0.2):
    query_emb = model.encode(sentence, convert_to_tensor=True)
    cos_sim = util.pytorch_cos_sim(query_emb, embeddings)
    cos_sim_series = pd.Series(cos_sim.numpy().flatten(), name='Relevance')
    return df.join(cos_sim_series[cos_sim_series >= rel_cap]).sort_values('Relevance', ascending=False).head(limit)[['Relevance','Scheme','Description', 'Agency', 'Image', 'Link']].to_json(orient="records")

# %%
df_schemes.to_csv('../models/transformer/source_data.csv')

# %%
# test reloading
df_reload = pd.read_csv('../models/transformer/source_data.csv')
emb = torch.load('../models/transformer/embeddings.pt')

# %%
rtn = return_query("single parent", emb, df_reload)

# %%
import json
json.loads(rtn)
# Out:
# [{'Relevance': 0.4312001467,
#   'Scheme': 'Home Ownership Plus Education (HOPE) Scheme',
#   'Description': 'Assistance for young, low-income parent(s) who choose to keep their family small so that they can focus their resources on giving their children a head start, and improve their financial and social situation. Includes grants and support for training, employment, utilities, housing, bursaries, mentoring and family support',
#   'Agency': 'Ministry of Social and Family Development (MSF)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/msf.jpg',
#   'Link': 'https://www.msf.gov.sg/assistance/Pages/Home-Ownership-Plus-Education-HOPE-Scheme.aspx'},
#  {'Relevance': 0.3013159037,
#   'Scheme': 'Various services',
#   'Description': 'Casework management; child protection; home-based parenting training; building psychological and social resilience for children and young persons; family bonding',
#   'Agency': 'Big Love Child Protection Specialist Centre',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/biglove.jpg',
#   'Link': 'https://www.biglove.org.sg/'},
#  {'Relevance': 0.2910259664,
#   'Scheme': 'Pregnancy Crisis and Support',
#   'Description': 'For emotional support, guidance, help and referrals that could facilitate a decision, whatever that decision may be.',
#   'Agency': 'Pregnancy Crisis and Support',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/pcs.jpg',
#   'Link': 'https://www.pregnancycrisis.sg/Home'},
#  {'Relevance': 0.2891668081,
#   'Scheme': 'Babes - A Helping Hand for Pregnant Teens',
#   'Description': 'Staff will discuss the various options available in order for client to make an informed decision. Provides support and linking with the appropriate resources, depending on what the situation requires.',
#   'Agency': 'Babes - A Helping Hand for Pregnant Teens',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/babes.jpg',
#   'Link': 'https://www.babes.org.sg/we-are-here-for-you/our-services/'},
#  {'Relevance': 0.2770137787,
#   'Scheme': 'Ministry of Education ñ Financial Assistance Scheme (MOE-FAS)',
#   'Description': 'Help needy Singaporean families reduce their burden in meeting essential school fees, expenses and to ensure that no child will be denied an education due to financial reasons.',
#   'Agency': 'Ministry of Education (MOE)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/moe.jpg',
#   'Link': 'https://beta.moe.gov.sg/fees-assistance-awards-scholarships/financial-assistance/'},
#  {'Relevance': 0.2663475871,
#   'Scheme': 'Various services',
#   'Description': 'Information relating to social service and referrals to appropriate services; casework & counselling; therapeutic groupwork',
#   'Agency': '@27 Family Service Centre',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/27fsc.jpg',
#   'Link': 'https://www.27fsc.org.sg/'},
#  {'Relevance': 0.2538147867,
#   'Scheme': "HIV+ Pregnant Mothers' Fund",
#   'Description': 'Assistance for HIV positive mothers who cannot afford anti-HIV treatment, in order to prevent transmission of HIV to their baby.',
#   'Agency': 'Action for AIDS (AFA)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/afa.jpg',
#   'Link': 'https://afa.org.sg/whatwedo/support/coordinatedcare/financialsupportprogrammes/#toggle-id-3'},
#  {'Relevance': 0.2480996251,
#   'Scheme': 'FaithActs Bursary Award',
#   'Description': 'Provide financial assistance to students from low-income families to purchase educational materials, complement the MOE FAS, and motivate beneficiary of the award.',
#   'Agency': 'FaithActs',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/faithacts.jpg',
#   'Link': 'https://www.faithacts.org.sg/services/community-care/bursary-awards'},
#  {'Relevance': 0.2460358441,
#   'Scheme': 'Fresh Start Housing Scheme',
#   'Description': 'The Fresh Start Housing Scheme (Fresh Start) aims to help second-timer (ST)1 families with young children, who are currently living in public rental flats. It assists them in owning a 2-room Flexi flat by integrating financial assistance with personal responsibility and social support.',
#   'Agency': 'Housing and Development Board (HDB)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/hdb.jpg',
#   'Link': 'https://www.hdb.gov.sg/cs/infoweb/residential/buying-a-flat/new/schemes-and-grants/fresh-start-housing-scheme'},
#  {'Relevance': 0.2451518178,
#   'Scheme': 'Various services',
#   'Description': 'Home and shelter for at-risk youth, providing alternative schooling, educational programmes, fostering services and other clinical interventions.',
#   'Agency': "Boys' Town",
#   'Image': 'https://chidnast.sirv.com/SchemesSG/boystown.jpg',
#   'Link': 'www.boystown.org.sg'},
#  {'Relevance': 0.2431408018,
#   'Scheme': 'The Straits Times School Pocket Money Fund',
#   'Description': 'To alleviate the financial burden faced by parents in providing for their childrenís education (school fees, expenses, etc). Funds will also help children who are already facing difficulties in remaining in school to stay on.',
#   'Agency': 'The Straits Times School Pocket Money Fund (SPMF)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/stspmf.jpg',
#   'Link': 'https://www.spmf.org.sg/primary-secondary-students'},
#  {'Relevance': 0.2428176105,
#   'Scheme': 'Family LifeAid',
#   'Description': 'Identified households receive food vouchers every month. Households will benefit from supplementary support, such as storytelling, tutoring of young children and helping the seniors with household chores. This will provide the opportunity for the children to advance in life. In addition, periodic reviews and assessments are carried out to monitor improvement or change in the familyís conditions, and to ensure that the dire needs of the families are met with the programme.',
#   'Agency': 'Red Cross Singapore',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/redcross.jpg',
#   'Link': 'https://www.redcross.sg/get-assistance/family-lifeaid.html'},
#  {'Relevance': 0.2376132011,
#   'Scheme': 'SAFE Programme (Stop Abuse in Families)',
#   'Description': 'TRANS SAFE Centre is a Family Violence Specialist Centre (FVSC). It aims to promote safe relationship in families by providing help to victims of abuse, persons who abuse and their families who are affected by the abuse.',
#   'Agency': 'Trans Family Services',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/trans.jpg',
#   'Link': 'https://www.trans.org.sg/index'},
#  {'Relevance': 0.2370239198,
#   'Scheme': 'Baby Bonus Scheme - Cash Gift',
#   'Description': 'Cash gift to defray the cost of raising and caregiving for your newborn child during the early years.',
#   'Agency': 'Ministry of Social and Family Development (MSF)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/msf.jpg',
#   'Link': 'https://www.babybonus.msf.gov.sg/wp-content/parent/documents/MSF_BabyBonus_Booklet_FA_Highres.pdf'},
#  {'Relevance': 0.2239897698,
#   'Scheme': 'Enhanced Pilot for Private Intervention Providers',
#   'Description': 'Subsidy scheme that offers more choices of early intervention programmes for children who have been referred for the Early Intervention Programme for Infants and Children (EIPIC). Parents who choose to enroll their children in selected Private Intervention Centres (PIC)s will receive subsidies that will help defray the enrolment costs.',
#   'Agency': 'SGEnable',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/sgenable.jpg',
#   'Link': 'https://www.sgenable.sg/pages/content.aspx?path=/schemes/intervention-programmes/enhanced-pilot-for-private-intervention-providers/'},
#  {'Relevance': 0.2148296833,
#   'Scheme': 'Children and youth services',
#   'Description': 'Children and youth services, particularly for at-risk youth and children. Includes suicide intervention, parent child mediation, handling beyond parental control, youth at risk services, befriender projects, workshops for probationers, services for children with special needs, and financial support for school pocket money and supplies.',
#   'Agency': 'NuLife Care & Counselling Services',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/nulife.jpg',
#   'Link': 'https://nulife.com.sg/counselling/'},
#  {'Relevance': 0.2113775611,
#   'Scheme': 'Cornerstone Development Initiatives (CDI) School Allowance',
#   'Description': 'A financial assistance scheme developed to give every child an opportunity to complete their foundational education despite their family circumstances. It is offered to Primary and Secondary students from low income families.',
#   'Agency': 'Cornerstone Community Services',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/cornerstone.jpg',
#   'Link': 'https://www.cornerstoneservices.org.sg/financial-aid'},
#  {'Relevance': 0.2084204853,
#   'Scheme': 'Family Development Programme',
#   'Description': 'Monthly financial assistance to help families cope with the cost of daily living expenses, childrenís educational expenses and milk powder supplements. Debt Clearance and Savings Matching Schemes to help families get out of debt',
#   'Agency': 'Methodist Welfare Services (MWS)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/mws.jpg',
#   'Link': 'https://mws.sg/centre-location/mws-family-development-programme/'},
#  {'Relevance': 0.2059007287,
#   'Scheme': 'Various services',
#   'Description': 'Information relating to social service and referrals to appropriate services; casework and counselling; therapeutic groupwork',
#   'Agency': 'Marine Parade Family Service Centre',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/mpfsc.jpg',
#   'Link': 'https://www.mpfsc.org.sg/'},
#  {'Relevance': 0.2043474764,
#   'Scheme': 'Financial Assistance and Food on the Table Program',
#   'Description': 'The objective of the Financial Assistance & Food on the Table Program is to provide support to Singaporean families in need for financial or other type of assistance.',
#   'Agency': 'Sikh Welfare Council',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/siwec.jpg',
#   'Link': 'https://www.siwec.org/our-services/family-support-services/financial-assistance-food-on-the-table'},
#  {'Relevance': 0.2022581249,
#   'Scheme': 'Tuition',
#   'Description': 'Free tuition to youth-at-risk',
#   'Agency': 'FaithActs',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/faithacts.jpg',
#   'Link': 'https://www.faithacts.org.sg/services/children-and-youth/tuition'},
#  {'Relevance': None,
#   'Scheme': 'Caregiver Training Program',
#   'Description': 'Provides training to caregivers of persons with mental health issues',
#   'Agency': 'Caregivers Alliance',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/CAL.jpg',
#   'Link': 'https://www.cal.org.sg/caregiver-training'},
#  {'Relevance': None,
#   'Scheme': 'Caregivers Support Centre',
#   'Description': 'Provides support to caregivers of persons with mental health issues',
#   'Agency': 'Caregivers Alliance',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/CAL.jpg',
#   'Link': 'https://www.cal.org.sg/caregivers-support-centre'},
#  {'Relevance': None,
#   'Scheme': 'Food Assistance',
#   'Description': 'A self setup group which distributes meal box to low income needy residents and senior citizens who residing in rented 1 or 2 rooms flats. Operates near the Bukit Merah region.',
#   'Agency': 'A Packet of Rice',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/apacketofrice.jpg',
#   'Link': 'https://www.facebook.com/APacketOfRice/'},
#  {'Relevance': None,
#   'Scheme': 'Assistance',
#   'Description': 'Bursaries, bread distribution and food rations, groceries and festive goodies, referral and counselling servies.',
#   'Agency': 'Filos Community Services',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/filos.jpg',
#   'Link': 'https://www.filos.sg/services-assistance'},
#  {'Relevance': None,
#   'Scheme': 'Assistance',
#   'Description': 'Various education subsidies, bursaries, study loans, scholarships, sponsorships and awards.',
#   'Agency': 'Yayasan MENDAKI',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/mendaki.jpg',
#   'Link': 'https://www.mendaki.org.sg/assistance-landing/'},
#  {'Relevance': None,
#   'Scheme': 'Assistance for Kidney Patients',
#   'Description': 'The programme provides assistance to needy kidney patients regardless of race and religion, and is available to both Singapore Citizens and Permanent Residents. Patients may apply for the assistance through medical social workers, and each case will be assessed by a Tzu Chi home visit team. Tzu Chi also provides transport allowances for patients with mobility problems who are unable to afford the transport costs of travelling between their home and the dialysis centre. Home visit teams will make care visits to beneficiary patients once a month, to monitor their health conditions as well as to give them moral support. Patients who are in need of further financial aid will be referred to the Foundation.',
#   'Agency': 'Buddhist Compassion Relief Tzu-Chi Foundation (Singapore)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/tzuchi.jpg',
#   'Link': 'https://www.tzuchi.org.sg/en/our-missions/charity/assistance-for-kidney-patients/'},
#  {'Relevance': None,
#   'Scheme': 'Assistive Technology Fund',
#   'Description': 'Subsidies for persons with disabilities (PWDs) to purchase assistive technology devices to enable independent living.Successful applicants qualify for a means-tested subsidy of up to 90% of the cost of the required equipment, subject to a lifetime cap of $40,000.',
#   'Agency': 'SGEnable',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/sgenable.jpg',
#   'Link': 'https://www.sgenable.sg/pages/content.aspx?path=/schemes/equipment-technology-home-retrofit/assistive-technology-fund/'},
#  {'Relevance': None,
#   'Scheme': 'Cancer Care Fund, Welfare Aid Fund, Cancer Treatment Fund',
#   'Description': 'The Cancer Care Fund is a one-time financial assistance scheme to alleviate the financial burden of newly-diagnosed cancer patients from low or middle income families within the first 6 months of diagnosis.The Welfare Aid fund provides temporary financial assistance and/or medical supplies to enhance the well-being of needy cancer patients. Medical supplies include the supply of milk, diapers, medical dressings, stoma bags and other medical equipment. The Cancer Treatment Fund provides financial assistance to needy cancer patients to subsidise part of their cancer treatment costs.',
#   'Agency': 'Singapore Cancer Society',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/scs.jpg',
#   'Link': 'https://www.singaporecancersociety.org.sg/get-help/cancer-patient/financial-assistance-schemes/apply-for-financial-assistance.html'},
#  {'Relevance': None,
#   'Scheme': 'Car Park Label Scheme For Persons With Physical Disabilities',
#   'Description': 'Car Park Label Scheme provides persons with physical disabilities or their caregivers with access to designated disabled parking spaces so that they can open the vehicle doors fully to board or alight from the vehicle.',
#   'Agency': 'SGEnable',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/sgenable.jpg',
#   'Link': 'https://www.sgenable.sg/pages/content.aspx?path=/schemes/accessibility/car-park-label-scheme-for-persons-with-physical-disabilities'},
#  {'Relevance': None,
#   'Scheme': 'Care for Family Fund',
#   'Description': 'Many people who are diagnosed with HIV will lose their jobs. Besides providing support to those directly impacted, we also recognise that support needs to reach caregivers or affected family and loved ones. This is subsidy is disbursed on an annual basis.',
#   'Agency': 'Action for AIDS (AFA)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/afa.jpg',
#   'Link': 'https://afa.org.sg/whatwedo/support/coordinatedcare/financialsupportprogrammes/#toggle-id-4'},
#  {'Relevance': None,
#   'Scheme': 'Career Matching Services',
#   'Description': 'Access to quick career tips, career advice and guidance. MyCareersFuture portal to help you search and apply for jobs that match your skills. Career preparatory workshops, networking sessions and walk-in interviews to improve your job search chances.',
#   'Agency': 'Workforce Singapore (WSG)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/wsg.jpg',
#   'Link': 'https://www.wsg.gov.sg/career-services.html'},
#  {'Relevance': None,
#   'Scheme': 'Caregivers Training Grant (CTG)',
#   'Description': 'Helps caregivers defray the cost of attending training to acquire the necessary knowledge and skills for better caregiving',
#   'Agency': 'Agency for Integrated Care (AIC)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/aic.jpg',
#   'Link': 'https://aic.sg/financial-assistance/caregivers-training-grant'},
#  {'Relevance': None,
#   'Scheme': 'CDAC-SFCCA Hardship Assistance Fund',
#   'Description': 'Short-term financial assistance to individuals who are facing financial hardship.',
#   'Agency': 'Chinese Development Assistance Council (CDAC), Singapore Federation of Chinese Clan Associations (SFCCA)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/cdac-sfcca.jpg',
#   'Link': 'https://www.cdac.org.sg/supporting-families/hardship-assistance-scheme/'},
#  {'Relevance': None,
#   'Scheme': 'Childcare & Infant Care Subsidy',
#   'Description': 'Subsidy to assist with defraying preschool expenses for Singaporean children',
#   'Agency': 'Early Childhood Development Agency (ECDA)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/ecda.jpg',
#   'Link': 'https://www.ecda.gov.sg/Pages/Subsidies-and-Financial-Assistance.aspx'},
#  {'Relevance': None,
#   'Scheme': 'ComCare Interim Assistance',
#   'Description': 'Urgent ComCare Assistance for those requiring immediate help for less than 3 months.',
#   'Agency': 'Ministry of Social and Family Development (MSF)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/msf.jpg',
#   'Link': 'https://www.msf.gov.sg/Comcare/Pages/Urgent-Financial-Assistance.aspx'},
#  {'Relevance': None,
#   'Scheme': 'ComCare Long Term Assistance',
#   'Description': 'Long-term ComCare assistance for those who are permanently unable to work.',
#   'Agency': 'Ministry of Social and Family Development (MSF)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/msf.jpg',
#   'Link': 'https://www.msf.gov.sg/Comcare/Pages/Public-Assistance.aspx'},
#  {'Relevance': None,
#   'Scheme': 'ComCare Short-To-Medium-Term Assistance',
#   'Description': 'Short to medium term assistance for those unable to find a job or work for a period of time and as a result, household needs financial help for a temporary period.',
#   'Agency': 'Ministry of Social and Family Development (MSF)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/msf.jpg',
#   'Link': 'https://www.msf.gov.sg/Comcare/Pages/Short-to-Medium-Term-Assistance.aspx'},
#  {'Relevance': None,
#   'Scheme': 'Comcare Student Care Fee Assistance (SCFA)',
#   'Description': 'Assistance for student are fees, for low-income households with children attending MSF-registered student care centres.',
#   'Agency': 'Ministry of Social and Family Development (MSF)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/msf.jpg',
#   'Link': 'https://www.msf.gov.sg/Comcare/Pages/ComCare-Student-Care-Subsidies.aspx'},
#  {'Relevance': None,
#   'Scheme': 'Community Health Assist Scheme',
#   'Description': 'Enables Singapore Citizens from lower- to middle-income households, and all Pioneers, to receive subsidies for medical & dental care at participating General Practitioners (GP) & dental clinics near their home.',
#   'Agency': 'Ministry of Health (MOH)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/MOH.jpg',
#   'Link': 'https://chas.moh.gov.sg/Home/Welcome'},
#  {'Relevance': None,
#   'Scheme': 'Compassion Fund',
#   'Description': 'Assist students whose families are in crisis, meaning the breadwinner inflicted by illness/met an accident that resulted in a loss of income, and/or death.',
#   'Agency': 'Compassion Fund Ltd',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/compassion.jpg',
#   'Link': 'https://www.cwa.org.sg/get-help/welfare-support'},
#  {'Relevance': None,
#   'Scheme': 'Cornerstone Development Initiatives (CDI) Redeemed',
#   'Description': 'A transport allowance scheme (for 3 months) aims at helping ex-offenders integrate back into society as they embark on a new job upon release. This scheme is applicable to ex-offenders who have secured employment and application can only be made by their employer.',
#   'Agency': 'Cornerstone Community Services',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/cornerstone.jpg',
#   'Link': 'https://www.cornerstoneservices.org.sg/financial-aid'},
#  {'Relevance': None,
#   'Scheme': 'COVID 19 related support',
#   'Description': 'Key government resource on COVID-19 related assistance.',
#   'Agency': 'Support Go Where',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/supportgowhere.jpg',
#   'Link': 'https://www.supportgowhere.gov.sg/schemes/?lang=english'},
#  {'Relevance': None,
#   'Scheme': 'COVID-19 - Family Assistance Fund',
#   'Description': 'Covid 19 Family Assistance Fund Fund will go towards the families whose household income and employment have been affected by the crisis. We disburse it in the form of cash and food vouchers.',
#   'Agency': 'Beyond Social Services',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/beyond.jpg',
#   'Link': 'https://www.beyond.org.sg/faf-faq/'},
#  {'Relevance': None,
#   'Scheme': 'CPF Housing Grants for DBSS Flats',
#   'Description': 'A suite of grants available for the Design, Build and Sell (DBSS) scheme',
#   'Agency': 'Housing and Development Board (HDB), Central Provident Fund (CPF)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/hdb-cpf.jpg',
#   'Link': 'https://www.hdb.gov.sg/cs/infoweb/residential/buying-a-flat/new/schemes-and-grants/cpf-housing-grants-for-dbss-flats'},
#  {'Relevance': None,
#   'Scheme': 'CPF Housing Grants for Executive Condominiums (Ecs)',
#   'Description': 'A suite of grants available for Executive Condominiums (ECs).',
#   'Agency': 'Housing and Development Board (HDB), Central Provident Fund (CPF)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/hdb-cpf.jpg',
#   'Link': 'https://www.hdb.gov.sg/cs/infoweb/residential/buying-a-flat/new/schemes-and-grants/cpf-housing-grants-for-ecs'},
#  {'Relevance': None,
#   'Scheme': 'CPF Housing Grants for HDB Flats',
#   'Description': 'On top of the subsidised purchase prices for new HDB flats, eligible buyers can also receive further subsidies in the form of CPF Housing Grants of up to $80,000.',
#   'Agency': 'Housing and Development Board (HDB), Central Provident Fund (CPF)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/hdb-cpf.jpg',
#   'Link': 'https://www.hdb.gov.sg/cs/infoweb/residential/buying-a-flat/new/schemes-and-grants/cpf-housing-grants-for-hdb-flats'},
#  {'Relevance': None,
#   'Scheme': 'Deferred Downpayment Scheme',
#   'Description': 'The Deferred Downpayment Scheme (DDS) enables elderly who are right-sizing to defer the payment of downpayment until key collection. This will help to ease the cash flow for elderly flat owners whose funds are tied up in their existing flat, and smoothen the right-sizing process.',
#   'Agency': 'Housing and Development Board (HDB)',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/hdb.jpg',
#   'Link': 'https://www.hdb.gov.sg/residential/living-in-an-hdb-flat/for-our-seniors/deferred-downpayment-scheme'},
#  {'Relevance': None,
#   'Scheme': 'Developmental Disabilities Registry Identity (DDRID) Card',
#   'Description': 'The DDRID card offers a benefits scheme that provides cardholders with discounted rates for services and access to various facilities. Cardholders can also enjoy discounted rates for products, services and access to facilities offered by participating companies',
#   'Agency': 'SGEnable',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/sgenable.jpg',
#   'Link': 'https://www.sgenable.sg/pages/content.aspx?path=/Schemes/Developmental-Disabilities-Registry+/'},
#  {'Relevance': None,
#   'Scheme': 'Dialysis Financial Assistance Scheme',
#   'Description': 'Dialysis Financial Assistance Scheme (ìDFASî) is a subsidy scheme to provide financial support for qualified MKAC patients, where funds are provided as assistance in meeting the cost of dialysis and related medication.',
#   'Agency': 'Muslim Kidney Action Association',
#   'Image': 'https://chidnast.sirv.com/SchemesSG/mkac.jpg',
#   'Link': 'https://www.mkac.sg/our-programmes/financial-assistance-scheme/'}]
