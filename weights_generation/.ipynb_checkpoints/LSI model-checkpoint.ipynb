# %%
import pandas as pd
import numpy as np
import spacy
import gensim
import operator
import re
import string
# Out:
# c:\python38\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
df_schemes = pd.read_csv('../schemes2.csv', encoding='mac_roman')
df_schemes.head()
# Out:
#                         Title                    Agency  \
# 0  Caregiver Training Program       Caregivers Alliance
# 1   Caregivers Support Centre       Caregivers Alliance
# 2              Family LifeAid       Red Cross Singapore
# 3             Food Assistance          A Packet of Rice
# 4                  Assistance  Filos Community Services
#
#                                          Description  \
# 0  Provides training to caregivers of persons wit...
# 1  Provides support to caregivers of persons with...
# 2  Identified households receive food vouchers ev...
# 3  A self setup group which distributes meal box ...
# 4  Bursaries, bread distribution and food rations...
#
#                    Who's it for  \
# 0                    Caregivers
# 1                    Caregivers
# 2  Low income,Need food support
# 3  Low income,Need food support
# 4  Low income,Need food support
#
#                                       What it gives  \
# 0             Educational programmes for caregivers
# 1                                    Emotional care
# 2  Financial assistance,Food,Educational programmes
# 3                                              Food
# 4                                  Food,Counselling
#
#                                                 Link  \
# 0          https://www.cal.org.sg/caregiver-training
# 1   https://www.cal.org.sg/caregivers-support-centre
# 2  https://www.redcross.sg/get-assistance/family-...
# 3            https://www.facebook.com/APacketOfRice/
# 4           https://www.filos.sg/services-assistance
#
#                                Background Image Link  \
# 0        https://chidnast.sirv.com/SchemesSG/CAL.jpg
# 1        https://chidnast.sirv.com/SchemesSG/CAL.jpg
# 2   https://chidnast.sirv.com/SchemesSG/redcross.jpg
# 3  https://chidnast.sirv.com/SchemesSG/apacketofr...
# 4      https://chidnast.sirv.com/SchemesSG/filos.jpg
#
#                  Scheme Type  \
# 0    Caregiver,Mental Health
# 1    Caregiver,Mental Health
# 2  Low Income,Food,Education
# 3            Low Income,Food
# 4            Low Income,Food
#
#                                   search_booster(WL)
# 0  Caregivers feeling overwhelmed. Burnout. Elder...
# 1  Caregivers feeling overwhelmed. Burnout. Elder...
# 2  My client needs help to get food, meal, hungry...
# 3  My client needs help to get food, meal, hungry...
# 4  Need to buy daily necessities, food, have not ...

# %%
#Create tag list
#df_schemes['Tags'] = [x for x in df_schemes[df_schemes.columns[5:8]].values]
#df_schemes['Tags'] = df_schemes['Tags'].apply(lambda x: [i for i in x if str(i) != "nan"])
#df_schemes

#Create concatenated column
df_schemes['Combined'] = df_schemes[['Description','search_booster(WL)']].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# %%
df_schemes
# Out:
#                            Title                              Agency  \
# 0     Caregiver Training Program                 Caregivers Alliance
# 1      Caregivers Support Centre                 Caregivers Alliance
# 2                 Family LifeAid                 Red Cross Singapore
# 3                Food Assistance                    A Packet of Rice
# 4                     Assistance            Filos Community Services
# ..                           ...                                 ...
# 155  Children and youth services  NuLife Care & Counselling Services
# 156     Services for individials  NuLife Care & Counselling Services
# 157            Legal Counselling  NuLife Care & Counselling Services
# 158          COVID-19 Assistance  NuLife Care & Counselling Services
# 159               Emergency Fund                       ONE Singapore
#
#                                            Description  \
# 0    Provides training to caregivers of persons wit...
# 1    Provides support to caregivers of persons with...
# 2    Identified households receive food vouchers ev...
# 3    A self setup group which distributes meal box ...
# 4    Bursaries, bread distribution and food rations...
# ..                                                 ...
# 155  Children and youth services, particularly for ...
# 156  Suicide intervention, emotional support, mid-c...
# 157  Mediation and negotiation, deed of separation,...
# 158  Information on various financial assistance sc...
# 159  Disburses money to assist low-income individua...
#
#                                   Who's it for  \
# 0                                   Caregivers
# 1                                   Caregivers
# 2                 Low income,Need food support
# 3                 Low income,Need food support
# 4                 Low income,Need food support
# ..                                         ...
# 155  Children,Youth-at-risk,Youth on probation
# 156               In need of mental healthcare
# 157                       In need of legal aid
# 158                Elderly,Families,Low income
# 159                                 Low income
#
#                                          What it gives  \
# 0                Educational programmes for caregivers
# 1                                       Emotional care
# 2     Financial assistance,Food,Educational programmes
# 3                                                 Food
# 4                                     Food,Counselling
# ..                                                 ...
# 155  Casework,Befriender services,Educational progr...
# 156  Casework,Befriender services,Emotional care,Co...
# 157                                     Legal services
# 158                                      Referral,Food
# 159                               Financial assistance
#
#                                                   Link  \
# 0            https://www.cal.org.sg/caregiver-training
# 1     https://www.cal.org.sg/caregivers-support-centre
# 2    https://www.redcross.sg/get-assistance/family-...
# 3              https://www.facebook.com/APacketOfRice/
# 4             https://www.filos.sg/services-assistance
# ..                                                 ...
# 155                 https://nulife.com.sg/counselling/
# 156                 https://nulife.com.sg/counselling/
# 157                 https://nulife.com.sg/counselling/
# 158           https://nulife.com.sg/covid-our-efforts/
# 159  http://onesingapore.org/take-action/emergency-...
#
#                                  Background Image Link  \
# 0          https://chidnast.sirv.com/SchemesSG/CAL.jpg
# 1          https://chidnast.sirv.com/SchemesSG/CAL.jpg
# 2     https://chidnast.sirv.com/SchemesSG/redcross.jpg
# 3    https://chidnast.sirv.com/SchemesSG/apacketofr...
# 4        https://chidnast.sirv.com/SchemesSG/filos.jpg
# ..                                                 ...
# 155     https://chidnast.sirv.com/SchemesSG/nulife.jpg
# 156     https://chidnast.sirv.com/SchemesSG/nulife.jpg
# 157     https://chidnast.sirv.com/SchemesSG/nulife.jpg
# 158     https://chidnast.sirv.com/SchemesSG/nulife.jpg
# 159  https://chidnast.sirv.com/SchemesSG/onesingapo...
#
#                               Scheme Type  \
# 0                 Caregiver,Mental Health
# 1                 Caregiver,Mental Health
# 2               Low Income,Food,Education
# 3                         Low Income,Food
# 4                         Low Income,Food
# ..                                    ...
# 155  Children,Youth-at-Risk,Mental Health
# 156                         Mental Health
# 157                             Legal Aid
# 158                         COVID-19,Food
# 159                            Low Income
#
#                                     search_booster(WL)  \
# 0    Caregivers feeling overwhelmed. Burnout. Elder...
# 1    Caregivers feeling overwhelmed. Burnout. Elder...
# 2    My client needs help to get food, meal, hungry...
# 3    My client needs help to get food, meal, hungry...
# 4    Need to buy daily necessities, food, have not ...
# ..                                                 ...
# 155  Child is rebellous, child hit parent, youth bu...
# 156  counselling, psycho-therapy, mental health, su...
# 157  Divorce, PPO, public protection order, legal, law
# 158  COVID, debt, pandemic, poor, hungry, nothing t...
# 159  Financial assistance, money for daily expenses...
#
#                                               Combined
# 0    Provides training to caregivers of persons wit...
# 1    Provides support to caregivers of persons with...
# 2    Identified households receive food vouchers ev...
# 3    A self setup group which distributes meal box ...
# 4    Bursaries, bread distribution and food rations...
# ..                                                 ...
# 155  Children and youth services, particularly for ...
# 156  Suicide intervention, emotional support, mid-c...
# 157  Mediation and negotiation, deed of separation,...
# 158  Information on various financial assistance sc...
# 159  Disburses money to assist low-income individua...
#
# [160 rows x 10 columns]

# %%
from spacy.lang.en.stop_words import STOP_WORDS
import string

spacy_nlp = spacy.load('en_core_web_sm')

#create list of punctuations and stopwords
punctuations = string.punctuation
stop_words = spacy.lang.en.stop_words.STOP_WORDS

#function for data cleaning and processing
#This can be further enhanced by adding / removing reg-exps as desired.

def spacy_tokenizer(sentence):
 
    #remove distracting single quotes
    sentence = re.sub('\'','',sentence)

    #replace extra spaces with single space
    sentence = re.sub(' +',' ',sentence)

    #remove unwanted lines starting from special charcters
    sentence = re.sub(r'\n: \'\'.*','',sentence)
    sentence = re.sub(r'\n!.*','',sentence)
    sentence = re.sub(r'^:\'\'.*','',sentence)
    
    #remove non-breaking new line characters
    sentence = re.sub(r'\n',' ',sentence)
    
    #remove punctuations
    sentence = re.sub(r'[^\w\s]',' ',sentence)
    
    #creating token object
    tokens = spacy_nlp(sentence)
    
    #lower, strip and lemmatize
    tokens = [word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in tokens]
    
    #remove stopwords, and exclude words less than 2 characters
    tokens = [word for word in tokens if word not in stop_words and word not in punctuations and len(word) > 2]
    
    #return tokens
    return tokens

# %%
# %time df_schemes['Tags_tokenized'] = df_schemes['Combined'].map(lambda x: spacy_tokenizer(x))

df_schemes
# Out:
# Wall time: 2.35 s
#                            Title                              Agency  \
# 0     Caregiver Training Program                 Caregivers Alliance
# 1      Caregivers Support Centre                 Caregivers Alliance
# 2                 Family LifeAid                 Red Cross Singapore
# 3                Food Assistance                    A Packet of Rice
# 4                     Assistance            Filos Community Services
# ..                           ...                                 ...
# 155  Children and youth services  NuLife Care & Counselling Services
# 156     Services for individials  NuLife Care & Counselling Services
# 157            Legal Counselling  NuLife Care & Counselling Services
# 158          COVID-19 Assistance  NuLife Care & Counselling Services
# 159               Emergency Fund                       ONE Singapore
#
#                                            Description  \
# 0    Provides training to caregivers of persons wit...
# 1    Provides support to caregivers of persons with...
# 2    Identified households receive food vouchers ev...
# 3    A self setup group which distributes meal box ...
# 4    Bursaries, bread distribution and food rations...
# ..                                                 ...
# 155  Children and youth services, particularly for ...
# 156  Suicide intervention, emotional support, mid-c...
# 157  Mediation and negotiation, deed of separation,...
# 158  Information on various financial assistance sc...
# 159  Disburses money to assist low-income individua...
#
#                                   Who's it for  \
# 0                                   Caregivers
# 1                                   Caregivers
# 2                 Low income,Need food support
# 3                 Low income,Need food support
# 4                 Low income,Need food support
# ..                                         ...
# 155  Children,Youth-at-risk,Youth on probation
# 156               In need of mental healthcare
# 157                       In need of legal aid
# 158                Elderly,Families,Low income
# 159                                 Low income
#
#                                          What it gives  \
# 0                Educational programmes for caregivers
# 1                                       Emotional care
# 2     Financial assistance,Food,Educational programmes
# 3                                                 Food
# 4                                     Food,Counselling
# ..                                                 ...
# 155  Casework,Befriender services,Educational progr...
# 156  Casework,Befriender services,Emotional care,Co...
# 157                                     Legal services
# 158                                      Referral,Food
# 159                               Financial assistance
#
#                                                   Link  \
# 0            https://www.cal.org.sg/caregiver-training
# 1     https://www.cal.org.sg/caregivers-support-centre
# 2    https://www.redcross.sg/get-assistance/family-...
# 3              https://www.facebook.com/APacketOfRice/
# 4             https://www.filos.sg/services-assistance
# ..                                                 ...
# 155                 https://nulife.com.sg/counselling/
# 156                 https://nulife.com.sg/counselling/
# 157                 https://nulife.com.sg/counselling/
# 158           https://nulife.com.sg/covid-our-efforts/
# 159  http://onesingapore.org/take-action/emergency-...
#
#                                  Background Image Link  \
# 0          https://chidnast.sirv.com/SchemesSG/CAL.jpg
# 1          https://chidnast.sirv.com/SchemesSG/CAL.jpg
# 2     https://chidnast.sirv.com/SchemesSG/redcross.jpg
# 3    https://chidnast.sirv.com/SchemesSG/apacketofr...
# 4        https://chidnast.sirv.com/SchemesSG/filos.jpg
# ..                                                 ...
# 155     https://chidnast.sirv.com/SchemesSG/nulife.jpg
# 156     https://chidnast.sirv.com/SchemesSG/nulife.jpg
# 157     https://chidnast.sirv.com/SchemesSG/nulife.jpg
# 158     https://chidnast.sirv.com/SchemesSG/nulife.jpg
# 159  https://chidnast.sirv.com/SchemesSG/onesingapo...
#
#                               Scheme Type  \
# 0                 Caregiver,Mental Health
# 1                 Caregiver,Mental Health
# 2               Low Income,Food,Education
# 3                         Low Income,Food
# 4                         Low Income,Food
# ..                                    ...
# 155  Children,Youth-at-Risk,Mental Health
# 156                         Mental Health
# 157                             Legal Aid
# 158                         COVID-19,Food
# 159                            Low Income
#
#                                     search_booster(WL)  \
# 0    Caregivers feeling overwhelmed. Burnout. Elder...
# 1    Caregivers feeling overwhelmed. Burnout. Elder...
# 2    My client needs help to get food, meal, hungry...
# 3    My client needs help to get food, meal, hungry...
# 4    Need to buy daily necessities, food, have not ...
# ..                                                 ...
# 155  Child is rebellous, child hit parent, youth bu...
# 156  counselling, psycho-therapy, mental health, su...
# 157  Divorce, PPO, public protection order, legal, law
# 158  COVID, debt, pandemic, poor, hungry, nothing t...
# 159  Financial assistance, money for daily expenses...
#
#                                               Combined  \
# 0    Provides training to caregivers of persons wit...
# 1    Provides support to caregivers of persons with...
# 2    Identified households receive food vouchers ev...
# 3    A self setup group which distributes meal box ...
# 4    Bursaries, bread distribution and food rations...
# ..                                                 ...
# 155  Children and youth services, particularly for ...
# 156  Suicide intervention, emotional support, mid-c...
# 157  Mediation and negotiation, deed of separation,...
# 158  Information on various financial assistance sc...
# 159  Disburses money to assist low-income individua...
#
#                                         Tags_tokenized
# 0    [provide, training, caregiver, person, mental,...
# 1    [provide, support, caregiver, person, mental, ...
# 2    [identify, household, receive, food, voucher, ...
# 3    [self, setup, group, distribute, meal, box, lo...
# 4    [bursary, bread, distribution, food, ration, g...
# ..                                                 ...
# 155  [child, youth, service, particularly, risk, yo...
# 156  [suicide, intervention, emotional, support, mi...
# 157  [mediation, negotiation, deed, separation, app...
# 158  [information, financial, assistance, scheme, h...
# 159  [disburse, money, assist, low, income, individ...
#
# [160 rows x 11 columns]

# %%
Description_to_match = df_schemes['Tags_tokenized']
Description_to_match[0:5]
# Out:
# 0    [provide, training, caregiver, person, mental,...
# 1    [provide, support, caregiver, person, mental, ...
# 2    [identify, household, receive, food, voucher, ...
# 3    [self, setup, group, distribute, meal, box, lo...
# 4    [bursary, bread, distribution, food, ration, g...
# Name: Tags_tokenized, dtype: object

# %%
#Word Cloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

series = pd.Series(np.concatenate(Description_to_match)).value_counts()[:100]
wordcloud = WordCloud(background_color='white').generate_from_frequencies(series)

plt.figure(figsize=(15,15), facecolor = None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#build word dictionary

from gensim import corpora

#creating term dictionary
# %time dictionary = corpora.Dictionary(Description_to_match)

#filter out terms which occurs in less than 4 documents and more than 20% of the documents.
#NOTE: Since we have smaller dataset, we will keep this commented for now.

#dictionary.filter_extremes(no_below=4, no_above=0.2)

#list of few which which can be further removed
stoplist = set('hello and if this can would should could tell ask come go')
stop_ids = [dictionary.token2id[stopword] for stopword in stoplist if stopword in dictionary.token2id]
dictionary.filter_tokens(stop_ids)
dictionary.save('dictionary')
# Out:
# Wall time: 9.94 ms

# %%
#print top 50 items from the dictionary with their unique token-id
dict_tokens = [[[dictionary[key], dictionary.token2id[dictionary[key]]] for key, value in dictionary.items() if key <= 50]]
print (dict_tokens)
# Out:
# [[['anymore', 0], ['burnout', 1], ['caregiver', 2], ['cope', 3], ['depress', 4], ['elderly', 5], ['feel', 6], ['health', 7], ['issue', 8], ['mental', 9], ['overwhelmed', 10], ['parent', 11], ['person', 12], ['provide', 13], ['stress', 14], ['training', 15], ['support', 16], ['addition', 17], ['advance', 18], ['assessment', 19], ['benefit', 20], ['carry', 21], ['change', 22], ['child', 23], ['childcare', 24], ['chore', 25], ['client', 26], ['condition', 27], ['day', 28], ['dire', 29], ['eat', 30], ['ensure', 31], ['family', 32], ['familyí', 33], ['food', 34], ['help', 35], ['household', 36], ['households', 37], ['hungry', 38], ['identify', 39], ['improvement', 40], ['life', 41], ['meal', 42], ['meet', 43], ['money', 44], ['monitor', 45], ['month', 46], ['need', 47], ['opportunity', 48], ['periodic', 49], ['programme', 50]]]

# %%
#Bag of words
corpus = [dictionary.doc2bow(desc) for desc in Description_to_match]
word_frequencies = [[(dictionary[id], frequency) for id, frequency in line] for line in corpus[0:3]]
print(word_frequencies)
# Out:
# [[('anymore', 1), ('burnout', 1), ('caregiver', 2), ('cope', 1), ('depress', 1), ('elderly', 1), ('feel', 1), ('health', 1), ('issue', 1), ('mental', 1), ('overwhelmed', 1), ('parent', 1), ('person', 1), ('provide', 1), ('stress', 1), ('training', 1)], [('anymore', 1), ('burnout', 1), ('caregiver', 2), ('cope', 1), ('depress', 1), ('elderly', 1), ('feel', 1), ('health', 1), ('issue', 1), ('mental', 1), ('overwhelmed', 1), ('parent', 1), ('person', 1), ('provide', 1), ('stress', 1), ('support', 1)], [('elderly', 1), ('provide', 1), ('support', 1), ('addition', 1), ('advance', 1), ('assessment', 1), ('benefit', 1), ('carry', 1), ('change', 1), ('child', 3), ('childcare', 1), ('chore', 2), ('client', 1), ('condition', 1), ('day', 1), ('dire', 1), ('eat', 1), ('ensure', 1), ('family', 1), ('familyí', 1), ('food', 2), ('help', 3), ('household', 3), ('households', 1), ('hungry', 1), ('identify', 1), ('improvement', 1), ('life', 1), ('meal', 1), ('meet', 1), ('money', 1), ('monitor', 1), ('month', 1), ('need', 5), ('opportunity', 1), ('periodic', 1), ('programme', 1), ('receive', 1), ('review', 1), ('senior', 1), ('storytelle', 1), ('supplementary', 1), ('tuition', 1), ('tutoring', 1), ('voucher', 1), ('young', 1)]]

# %%
#TF IDF and LSI
# %time schemes_tfidf_model = gensim.models.TfidfModel(corpus, id2word=dictionary)
schemes_tfidf_model.save("tfidf.model")
# %time schemes_lsi_model = gensim.models.LsiModel(schemes_tfidf_model[corpus], id2word=dictionary, num_topics=300)
schemes_lsi_model.save("lsi.model")
# Out:
# Wall time: 4.98 ms
# Wall time: 508 ms

# %%
# %time gensim.corpora.MmCorpus.serialize('schemes_tfidf_model_mm', schemes_tfidf_model[corpus])
# %time gensim.corpora.MmCorpus.serialize('schemes_lsi_model_mm',schemes_lsi_model[schemes_tfidf_model[corpus]])
# Out:
# Wall time: 50.8 ms
# Wall time: 101 ms

# %%
#Load indexed corpus
schemes_tfidf_corpus = gensim.corpora.MmCorpus('schemes_tfidf_model_mm')
schemes_lsi_corpus = gensim.corpora.MmCorpus('schemes_lsi_model_mm')

print(schemes_tfidf_corpus)
print(schemes_lsi_corpus)
# Out:
# MmCorpus(160 documents, 1311 features, 3910 non-zero entries)
# MmCorpus(160 documents, 160 features, 25286 non-zero entries)

# %%
from gensim.similarities import MatrixSimilarity

# %time schemes_index = MatrixSimilarity(schemes_lsi_corpus, num_features = schemes_lsi_corpus.num_terms)
# Out:
# Wall time: 71.3 ms

# %%
#Search similarity

from operator import itemgetter

def search_similar_schemes(search_term):
    query_bow = dictionary.doc2bow(spacy_tokenizer(search_term))
    query_tfidf = schemes_tfidf_model[query_bow]
    query_lsi = schemes_lsi_model[query_tfidf]

    schemes_index.num_best = 50

    schemes_list = schemes_index[query_lsi]

    schemes_list.sort(key=itemgetter(1), reverse=True)
    schemes_names = []

    for j, scheme in enumerate(schemes_list):

        schemes_names.append (
            {
                'Relevance': round((scheme[1] * 100),2),
                'Scheme Title': df_schemes['Title'][scheme[0]],
                'Description': df_schemes['Description'][scheme[0]]
            }

        )
        if j == (schemes_index.num_best-1):
            break

    return pd.DataFrame(schemes_names, columns=['Relevance','Scheme Title','Description'])

# %%
search_similar_schemes('pregnant teen')
# Out:
#     Relevance                                       Scheme Title  \
# 0       85.04                       Pregnancy Crisis and Support
# 1       69.57          Babes - A Helping Hand for Pregnant Teens
# 2       48.39                                        Information
# 3        0.00                              Home Access Programme
# 4        0.00                                   Various services
# 5        0.00                                       iNSPIRE Fund
# 6        0.00                    MUIS Special Needs Trust Scheme
# 7        0.00                           Enhanced Screen for Life
# 8        0.00                                      SINDA Bursary
# 9        0.00                               Financial Assistance
# 10       0.00          Seniors' Mobility and Enabling Fund (SMF)
# 11       0.00            SAFE Programme (Stop Abuse in Families)
# 12       0.00  Subsidised Haemodialysis and Portable Subsidy ...
# 13       0.00  Financial and Food Rations assistance (Temporary)
# 14       0.00        Home Ownership Plus Education (HOPE) Scheme
# 15       0.00                   Tabung Amal Aidifitri Trust Fund
# 16       0.00                              Financial Asssistance
# 17       0.00                               Financial Assistance
# 18       0.00  Cornerstone Development Initiatives (CDI) Scho...
# 19       0.00       Financial Assistance Schemes & Food Vouchers
# 20       0.00                        HIV+ Pregnant Mothers' Fund
# 21       0.00  Subsidies for Services and Drugs at Public Hea...
# 22      -0.00                      Financial Assistance Measures
# 23      -0.00                               Financial Assistance
# 24      -0.00                    Childcare & Infant Care Subsidy
# 25      -0.00  Hematopoietic Progenitor Cells (HPC) Procureme...
# 26      -0.00                                   CLG Legal Clinic
# 27      -0.00                                            Tuition
# 28      -0.00                              SINDA Job Care Scheme
# 29      -0.00                               Financial Assistance
# 30      -0.00                                           Casework
# 31      -0.00                               Financial Assistance
# 32      -0.00  Transport Subsidy and Assistive Device & Equip...
# 33      -0.00                                   Elderly services
# 34      -0.00  Enhanced Pilot for Private Intervention Providers
# 35      -0.00                     Assistance for Kidney Patients
# 36      -0.00                       VWO Transport Subsidy Scheme
# 37      -0.00  Cancer Care Fund, Welfare Aid Fund, Cancer Tre...
# 38      -0.00      Shelter of Displaced Families and Individuals
# 39      -0.00                          Caregivers Support Centre
# 40      -0.00                          Mobile Access for Seniors
# 41      -0.00                               Financial Assistance
# 42      -0.00                       Staggered Downpayment Scheme
# 43      -0.00                  Matched Retirement Savings Scheme
# 44      -0.00         Kindergarten Fee Assistance Scheme (KiFAS)
# 45      -0.00                               Lease Buyback Scheme
# 46      -0.00                                    Compassion Fund
# 47      -0.00                                         Assistance
# 48      -0.00                                     LBKM Bursaries
# 49      -0.00                    Caregivers Training Grant (CTG)
#
#                                           Description
# 0   For emotional support, guidance, help and refe...
# 1   Staff will discuss the various options availab...
# 2   Information on various issues, including contr...
# 3   Home Access provides eligible Singaporean fami...
# 4   Provides rehabilitation and emotional support ...
# 5   The iNSPIRE Fund scheme offers financial assis...
# 6   Eligible families with PSNs will receive suppo...
# 7   Screen for Life (SFL) is a national screening ...
# 8   SINDA Bursary supports low-income and deservin...
# 9   Financial assistance for psychological assessm...
# 10  Provides holistic support for seniors to age i...
# 11  TRANS SAFE Centre is a Family Violence Special...
# 12  The subsidised haemodialysis programme at KDF ...
# 13  To provide temporary aid to individuals and/or...
# 14  Assistance for young, low-income parent(s) who...
# 15  TAA Trust Fund (Tabung Amal Aidilfitri Trust F...
# 16  CCF Financial Assistance (FA) scheme aims to h...
# 17  Cancer treatment can place a heavy financial b...
# 18  A financial assistance scheme developed to giv...
# 19  Provides information and referrals to social w...
# 20  Assistance for HIV positive mothers who cannot...
# 21  The Ministry of Health (MOH) provides subsidie...
# 22  As a safety net, we have Financial Assistance ...
# 23  Bi-monthly Zakat distribution through monetary...
# 24  Subsidy to assist with defraying preschool exp...
# 25  Subsidies to offset Hematopoietic Progenitor C...
# 26  It provides legal assistance for the poor, dis...
# 27                      Free tuition to youth-at-risk
# 28  SINDAís Job Care Scheme (SINDA JCS) is to assi...
# 29  We offer short-term financial assistance to th...
# 30  Casework management for those facing financial...
# 31  Our financial assistance schemes help to allev...
# 32  Members are provided up to 100% subsidy on a c...
# 33  Suicide intervention, befriender services, han...
# 34  Subsidy scheme that offers more choices of ear...
# 35  The programme provides assistance to needy kid...
# 36  Up to 80% subsidy for transport fees supportin...
# 37  The Cancer Care Fund is a one-time financial a...
# 38  Temporary housing for homeless families, while...
# 39  Provides support to caregivers of persons with...
# 40  Mobile Access for Seniors is a scheme that sup...
# 41  Every month, our volunteers visit each ìadopte...
# 42  You may be able to use the Staggered Downpayme...
# 43  Implemented in 2021 to help senior Singaporean...
# 44  Means-tested subsidy ranging $21 to $170 to as...
# 45  Through the Lease Buyback Scheme (LBS), you wi...
# 46  Assist students whose families are in crisis, ...
# 47  Various education subsidies, bursaries, study ...
# 48  Various education bursaries for primary to pos...
# 49  Helps caregivers defray the cost of attending ...

# %%
import flask
print(flask.__version__)
# Out:
# 1.1.2
