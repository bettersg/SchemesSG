# %%
import pandas as pd
import numpy as np
import re
import string

# %%
df_schemes = pd.read_csv('df.csv', encoding='mac_roman')
df_schemes
# Out:
#                                        Scheme  \
# 0                            Various services
# 1                        Financial Assistance
# 2                             Food Assistance
# 3    Rehabilitation Centre and Respite Centre
# 4                            Various Services
# ..                                        ...
# 275                  Career Matching Services
# 276      Workfare Skills Support (WSS) Scheme
# 277                                Assistance
# 278                          Various services
# 279                                YMCA FACES
#
#                                            Description  \
# 0    Information relating to social service and ref...
# 1    Cancer treatment can place a heavy financial b...
# 2    A self setup group which distributes meal box ...
# 3    Provides Occupational Therapy, Physiotherapy a...
# 4    We prepare educational programs (IT Training) ...
# ..                                                 ...
# 275  Access to quick career tips, career advice and...
# 276  WSS encourages low wage workers to undertake t...
# 277  Various education subsidies, bursaries, study ...
# 278  We galvanise society to uplift ex-offenders th...
# 279  Short term financial assistance, bridging fund...
#
#                                                 Agency  \
# 0                            @27 Family Service Centre
# 1               365 Cancer Prevention Society (365CPS)
# 2                                     A Packet of Rice
# 3    Abilities Beyond Limitations and Expectations ...
# 4                                   Acronis Foundation
# ..                                                 ...
# 275                          Workforce Singapore (WSG)
# 276                          Workforce Singapore (WSG)
# 277                                    Yayasan MENDAKI
# 278                            Yellow Ribbon Singapore
# 279           Young Men's Christian Association (YMCA)
#
#                                                  Image  \
# 0        https://chidnast.sirv.com/SchemesSG/27fsc.jpg
# 1       https://chidnast.sirv.com/SchemesSG/365cps.jpg
# 2    https://chidnast.sirv.com/SchemesSG/apacketofr...
# 3         https://chidnast.sirv.com/SchemesSG/able.jpg
# 4      https://chidnast.sirv.com/SchemesSG/acronis.jpg
# ..                                                 ...
# 275        https://chidnast.sirv.com/SchemesSG/wsg.jpg
# 276        https://chidnast.sirv.com/SchemesSG/wsg.jpg
# 277    https://chidnast.sirv.com/SchemesSG/mendaki.jpg
# 278  https://chidnast.sirv.com/SchemesSG/yellowribb...
# 279       https://chidnast.sirv.com/SchemesSG/ymca.jpg
#
#                                                   Link  \
# 0                            https://www.27fsc.org.sg/
# 1    https://365cps.org.sg/portfolio/financial-supp...
# 2              https://www.facebook.com/APacketOfRice/
# 3                             https://www.able-sg.org/
# 4       https://acronis.org/rehabilitation-of-inmates/
# ..                                                 ...
# 275        https://www.wsg.gov.sg/career-services.html
# 276  https://www.wsg.gov.sg/programmes-and-initiati...
# 277     https://www.mendaki.org.sg/assistance-landing/
# 278  https://www.yellowribbon.gov.sg/partnership-pr...
# 279  https://www.ymca.org.sg/community-services/fin...
#
#                                           Who's it for  \
# 0                                             Families
# 1                                      Cancer patients
# 2                         Low income,Need food support
# 3                               PWD,Elderly,Caregivers
# 4                                         Ex-offenders
# ..                                                 ...
# 275                          Retrenched,In need of job
# 276                        Low wage workers,Low income
# 277  Low income,Need education assistance,Need food...
# 278                                       Ex-offenders
# 279  Low income,Low income families,Persons with sp...
#
#                                          What it gives  \
# 0                                 Counselling,Casework
# 1            Financial assistance for cancer treatment
# 2                                                 Food
# 3    Occupational therapy,Physiotherapy,Educational...
# 4            Vocational training,Employment assistance
# ..                                                 ...
# 275                              Employment assistance
# 276  Employment assistance,Financial assistance for...
# 277   Financial assistance,Food,Educational programmes
# 278          Employment assistance,Vocational training
# 279  Financial assistance for daily needs,Employmen...
#
#                                        Scheme Type  \
# 0                                Low Income,Family
# 1                            Low Income,Healthcare
# 2                                  Low Income,Food
# 3    PWD,Family,Transport,Healthcare,Mental Health
# 4                           Ex-offender,Employment
# ..                                             ...
# 275                                           Work
# 276                                           Work
# 277                           Low Income,Education
# 278                    Ex-offender,Work,Employment
# 279                Low Income,Special Needs,Family
#
#                                     search_booster(WL)
# 0    social service, individuals, families, casewor...
# 1                         See doctor, cancer, oncology
# 2    Needs help to get food, meal, hungry, have not...
# 3    rehabilitation, occupational therapy, physioth...
# 4    ex-convict need job, ex-convict skills trainin...
# ..                                                 ...
# 275  In need of a job, need to find a job fast. Job...
# 276     Low income, upskill, low wage workers,training
# 277  Preschool, tuition fee, NITEC, polytechnic, Ma...
# 278  ex-convict social program, ex-convict need job...
# 279  Financial assistance, money for daily expenses...
#
# [280 rows x 9 columns]

# %%
formatted = pd.DataFrame(columns=('Scheme','Description','Agency','Image','Link','Scheme Type', "Who It's For", "What It Gives"))

for i in range(len(df_schemes)): 
    for j in range(len(df_schemes.iloc[i]['Scheme Type'].split(','))):
        for k in range(len(df_schemes.iloc[i]["Who's it for"].split(','))):
            for l in range(len(df_schemes.iloc[i]["What it gives"].split(','))):
                new_row = {'Scheme':df_schemes.iloc[i]['Scheme'],
                               'Description':df_schemes.iloc[i]['Description'],
                               'Agency':df_schemes.iloc[i]['Agency'],
                               'Image':df_schemes.iloc[i]['Image'],
                               'Link':df_schemes.iloc[i]['Link'],
                               'Scheme Type':df_schemes.iloc[i]['Scheme Type'].split(',')[j],
                               "Who It's For":df_schemes.iloc[i]["Who's it for"].split(',')[k],
                               "What It Gives":df_schemes.iloc[i]["What it gives"].split(',')[l]}
                formatted = formatted.append(new_row, ignore_index=True)

# %%
formatted.to_csv('formatted.csv')
