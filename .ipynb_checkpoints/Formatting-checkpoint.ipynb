# %%
import pandas as pd
import numpy as np
import re
import string

# %%
df_schemes = pd.read_csv('df.csv', encoding='mac_roman')
df_schemes
# Out:
#                                                 Scheme  \
# 0                                     Various services
# 1                                 Financial Assistance
# 2                                      Food Assistance
# 3             Rehabilitation Centre and Respite Centre
# 4                                     Various Services
# ..                                                 ...
# 336                                  Something-New App
# 337                                 MINDS Me Too! Club
# 338  Our Lives Our Voices (OLOV) Self-advocacy Prog...
# 339                                  MINDS Care Circle
# 340         Huggies Singapore Diaper Bank @ North West
#
#                                            Description  \
# 0    Information relating to social service and ref...
# 1    Cancer treatment can place a heavy financial b...
# 2    A self setup group which distributes meal box ...
# 3    Provides Occupational Therapy, Physiotherapy a...
# 4    We prepare educational programs (IT Training) ...
# ..                                                 ...
# 336  The first e-platform the human would think of ...
# 337  Through our exciting array of leisure and befr...
# 338  A structured programme to help persons with in...
# 339  A safe community for caregivers of persons wit...
# 340  Free 6 packs of diapers for lower income house...
#
#                                                 Agency  FSC  \
# 0                            @27 Family Service Centre  Yes
# 1               365 Cancer Prevention Society (365CPS)  NaN
# 2                                     A Packet of Rice  NaN
# 3    Abilities Beyond Limitations and Expectations ...  NaN
# 4                                   Acronis Foundation  NaN
# ..                                                 ...  ...
# 336      Singapore Planned Families Association (SPFA)  NaN
# 337  Movement for the Intellectually Disabled of Si...  NaN
# 338  Movement for the Intellectually Disabled of Si...  NaN
# 339  Movement for the Intellectually Disabled of Si...  NaN
# 340   North West Community Development Council (NWCDC)  NaN
#
#                                                  Image  \
# 0        https://chidnast.sirv.com/SchemesSG/27fsc.jpg
# 1       https://chidnast.sirv.com/SchemesSG/365cps.jpg
# 2    https://chidnast.sirv.com/SchemesSG/apacketofr...
# 3         https://chidnast.sirv.com/SchemesSG/able.jpg
# 4      https://chidnast.sirv.com/SchemesSG/acronis.jpg
# ..                                                 ...
# 336       https://chidnast.sirv.com/SchemesSG/spfa.jpg
# 337      https://chidnast.sirv.com/SchemesSG/minds.jpg
# 338      https://chidnast.sirv.com/SchemesSG/minds.jpg
# 339      https://chidnast.sirv.com/SchemesSG/minds.jpg
# 340      https://chidnast.sirv.com/SchemesSG/nwcdc.jpg
#
#                                                   Link  \
# 0                            https://www.27fsc.org.sg/
# 1    https://365cps.org.sg/portfolio/financial-supp...
# 2              https://www.facebook.com/APacketOfRice/
# 3                             https://www.able-sg.org/
# 4       https://acronis.org/rehabilitation-of-inmates/
# ..                                                 ...
# 336  https://apps.apple.com/sg/app/something-new/id...
# 337           https://www.minds.org.sg/for-adults/mtc/
# 338  https://www.minds.org.sg/for-adults/self-advoc...
# 339  https://www.minds.org.sg/for-caregivers/minds-...
# 340                        https://go.gov.sg/nwdiapers
#
#                                           Who's it for  \
# 0                                             Families
# 1                                      Cancer patients
# 2                         Low income,Need food support
# 3                               PWD,Elderly,Caregivers
# 4                                         Ex-offenders
# ..                                                 ...
# 336                       In need of mental healthcare
# 337  Persons with intellectual disability,Persons w...
# 338  Persons with Intellectual Disability, Persons ...
# 339  Persons with Intellectual Disability, Persons ...
# 340                Low income families,Babies,Children
#
#                                          What it gives  \
# 0                                 Counselling,Casework
# 1            Financial assistance for cancer treatment
# 2                                                 Food
# 3    Occupational therapy,Physiotherapy,Educational...
# 4            Vocational training,Employment assistance
# ..                                                 ...
# 336                                        Counselling
# 337  Peer support, Social Support, Befriending, Soc...
# 338  Peer support, Social Support, Befriending, Sel...
# 339    Peer support, Social Support, Caregiver support
# 340                               Diapers for children
#
#                                            Scheme Type  \
# 0                                    Low Income,Family
# 1                                Low Income,Healthcare
# 2                                      Low Income,Food
# 3        PWD,Family,Transport,Healthcare,Mental Health
# 4                               Ex-offender,Employment
# ..                                                 ...
# 336                         Counselling, mental health
# 337  Befriending for persons with intellectual disa...
# 338  Self-advocacy training for persons with intell...
# 339                            Caregiver Support Group
# 340                           Low income, baby diapers
#
#                                     search_booster(WL)
# 0    social service, individuals, families, casewor...
# 1                         See doctor, cancer, oncology
# 2    Needs help to get food, meal, hungry, have not...
# 3    rehabilitation, occupational therapy, physioth...
# 4    ex-convict need job, ex-convict skills trainin...
# ..                                                 ...
# 336  free online counselling, mobile application, m...
# 337  befriending, socialising, club, friends, socia...
# 338  befriending, socialising, club, friends, socia...
# 339  caregiving, caring, intellectual disability, I...
# 340  free diapers, baby diapers, low income, financ...
#
# [341 rows x 10 columns]

# %%
formatted = pd.DataFrame(columns=('Scheme','Description','Agency','Image','Link',"Who It's For", "What It Gives", 'Scheme Type'))

for i in range(len(df_schemes)): 
    for j in range(len(df_schemes.iloc[i]["Who's it for"].split(','))):
        for k in range(len(df_schemes.iloc[i]["What it gives"].split(','))):
            for l in range(len(df_schemes.iloc[i]["Scheme Type"].split(','))):
                new_row = {'Scheme':df_schemes.iloc[i]['Scheme'],
                               'Description':df_schemes.iloc[i]['Description'],
                               'Agency':df_schemes.iloc[i]['Agency'],
                               'Image':df_schemes.iloc[i]['Image'],
                               'Link':df_schemes.iloc[i]['Link'],
                               "Who It's For":df_schemes.iloc[i]["Who's it for"].split(',')[j],
                               "What It Gives":df_schemes.iloc[i]["What it gives"].split(',')[k],
                               "Scheme Type":df_schemes.iloc[i]['Scheme Type'].split(',')[l]}
                formatted = formatted.append(new_row, ignore_index=True)

# %%
formatted.to_csv('formatted.csv')
